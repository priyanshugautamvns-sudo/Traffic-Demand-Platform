# %% [markdown]
# # Traffic Demand Prediction Training Notebook
#
# This notebook reproduces the hackathon pipeline: leakage-safe encodings, LightGBM folds, validation metrics, and submission generation.

# %%
from backend.app.train import load_data, train_model
from backend.app.service import project_root
import json

root = project_root()
root

# %% [markdown]
# ## Data Loading
#
# The pipeline expects `train.csv` and `test.csv` in the local data folder or the paths supplied through environment variables.

# %%
train_df, test_df = load_data()
train_df.head()

# %% [markdown]
# ## Train And Generate Submission
#
# This runs the full KFold LightGBM pipeline and writes `outputs/submission.csv`.

# %%
result = train_model(train_df, test_df)
result['bundle'].metrics

# %% [markdown]
# ## Submission Preview
#
# The first rows of the generated submission are shown below.

# %%
result['submission_preview']
